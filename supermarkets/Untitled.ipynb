# %%
import os
os.listdir()
# Out:
# ['.ipynb_checkpoints',
#  'supermarkets-commas.txt',
#  'supermarkets-semi-colons.txt',
#  'supermarkets.csv',
#  'supermarkets.json',
#  'supermarkets.xlsx',
#  'Untitled.ipynb']

# %%
import pandas

# %%
df1=pandas.read_csv("supermarkets.csv")
df1
# Out:
#    ID          Address           City             State Country         Name  \
# 0   1     3666 21st St  San Francisco          CA 94114     USA      Madeira
# 1   2   735 Dolores St  San Francisco          CA 94119     USA  Bready Shop
# 2   3      332 Hill St  San Francisco  California 94114     USA  Super River
# 3   4     3995 23rd St  San Francisco          CA 94114     USA   Ben's Shop
# 4   5  1056 Sanchez St  San Francisco        California     USA      Sanchez
# 5   6  551 Alvarado St  San Francisco          CA 94114     USA   Richvalley
#
#    Employees
# 0          8
# 1         15
# 2         25
# 3         10
# 4         12
# 5         20

# %%
df2=pandas.read_json('supermarkets.json')
df2
# Out:
#    ID          Address           City             State Country         Name  \
# 0   1     3666 21st St  San Francisco          CA 94114     USA      Madeira
# 1   2   735 Dolores St  San Francisco          CA 94119     USA  Bready Shop
# 2   3      332 Hill St  San Francisco  California 94114     USA  Super River
# 3   4     3995 23rd St  San Francisco          CA 94114     USA   Ben's Shop
# 4   5  1056 Sanchez St  San Francisco        California     USA      Sanchez
# 5   6  551 Alvarado St  San Francisco          CA 94114     USA   Richvalley
#
#    Employees
# 0          8
# 1         15
# 2         25
# 3         10
# 4         12
# 5         20

# %%
import json
df3=json.load(open('supermarkets.json'))
df3
# Out:
# [{'ID': 1,
#   'Address': '3666 21st St',
#   'City': 'San Francisco',
#   'State': 'CA 94114',
#   'Country': 'USA',
#   'Name': 'Madeira',
#   'Employees': 8},
#  {'ID': 2,
#   'Address': '735 Dolores St',
#   'City': 'San Francisco',
#   'State': 'CA 94119',
#   'Country': 'USA',
#   'Name': 'Bready Shop',
#   'Employees': 15},
#  {'ID': 3,
#   'Address': '332 Hill St',
#   'City': 'San Francisco',
#   'State': 'California 94114',
#   'Country': 'USA',
#   'Name': 'Super River',
#   'Employees': 25},
#  {'ID': 4,
#   'Address': '3995 23rd St',
#   'City': 'San Francisco',
#   'State': 'CA 94114',
#   'Country': 'USA',
#   'Name': "Ben's Shop",
#   'Employees': 10},
#  {'ID': 5,
#   'Address': '1056 Sanchez St',
#   'City': 'San Francisco',
#   'State': 'California',
#   'Country': 'USA',
#   'Name': 'Sanchez',
#   'Employees': 12},
#  {'ID': 6,
#   'Address': '551 Alvarado St',
#   'City': 'San Francisco',
#   'State': 'CA 94114',
#   'Country': 'USA',
#   'Name': 'Richvalley',
# ...

# %%
df4=pandas.read_xlsx('supermarkets.xlsx')
df4
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-5d976d62be14> in <module>
# ----> 1 df4=pandas.read_xlsx('supermarkets.xlsx')
#       2 df4
#
# NameError: name 'pandas' is not defined

# %%
df4=pandas.read_xlsx('supermarkets.xlsx')
df4
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-5d976d62be14> in <module>
# ----> 1 df4=pandas.read_xlsx('supermarkets.xlsx')
#       2 df4
#
# NameError: name 'pandas' is not defined

# %%
import pandas
df4=pandas.read_excel('supermarkets.xlsx')
df4
# Out:
#    ID          Address           City             State Country  \
# 0   1     3666 21st St  San Francisco          CA 94114     USA
# 1   2   735 Dolores St  San Francisco          CA 94119     USA
# 2   3      332 Hill St  San Francisco  California 94114     USA
# 3   4     3995 23rd St  San Francisco          CA 94114     USA
# 4   5  1056 Sanchez St  San Francisco        California     USA
# 5   6  551 Alvarado St  San Francisco          CA 94114     USA
#
#   Supermarket Name  Number of Employees
# 0          Madeira                    8
# 1      Bready Shop                   15
# 2      Super River                   25
# 3       Ben's Shop                   10
# 4          Sanchez                   12
# 5       Richvalley                   20

# %%
df5=pandas.read_csv('supermarkets-semi-colons.txt')
df5
# Out:
#         ID;Address;City;State;Country;Name;Employees
# 0  1;3666 21st St;San Francisco;CA 94114;USA;Made...
# 1  2;735 Dolores St;San Francisco;CA 94119;USA;Br...
# 2  3;332 Hill St;San Francisco;California 94114;U...
# 3  4;3995 23rd St;San Francisco;CA 94114;USA;Ben'...
# 4  5;1056 Sanchez St;San Francisco;California;USA...
# 5  6;551 Alvarado St;San Francisco;CA 94114;USA;R...

# %%
pandas.read?
# Out:
# Object `pandas.read` not found.

# %%
pandas.read_csv?

# %%
df5=pandas.read_csv('supermarkets-semi-colons.txt', sep=';')
df5
# Out:
#    ID          Address           City             State Country          Name  \
# 0   1     3666 21st St  San Francisco          CA 94114     USA       Madeira
# 1   2   735 Dolores St  San Francisco          CA 94119     USA   Bready Shop
# 2   3      332 Hill St  San Francisco  California 94114     USA   Super River
# 3   4     3995 23rd St  San Francisco          CA 94114     USA    Ben's Shop
# 4   5  1056 Sanchez St  San Francisco        California     USA       Sanchez
# 5   6  551 Alvarado St  San Francisco          CA 94114     USA    Richvalley
#
#    Employees
# 0          8
# 1         15
# 2         25
# 3         10
# 4         12
# 5         20

# %%
df6=pandas.read_csv('supermarkets.txt',header=None)
df6
# Out:
#    0                1              2                 3    4            5   6
# 0  1     3666 21st St  San Francisco          CA 94114  USA      Madeira   8
# 1  2   735 Dolores St  San Francisco          CA 94119  USA  Bready Shop  15
# 2  3      332 Hill St  San Francisco  California 94114  USA  Super River  25
# 3  4     3995 23rd St  San Francisco          CA 94114  USA   Ben's Shop  10
# 4  5  1056 Sanchez St  San Francisco        California  USA      Sanchez  12
# 5  6  551 Alvarado St  San Francisco          CA 94114  USA   Richvalley  20

# %%
df6.columns=["ID","ADDRESS","CITY","ZIP","COUNTRY","NAME","EMPLOYEES"]

# %%
df6
# Out:
#    ID          ADDRESS           CITY               ZIP COUNTRY         NAME  \
# 0   1     3666 21st St  San Francisco          CA 94114     USA      Madeira
# 1   2   735 Dolores St  San Francisco          CA 94119     USA  Bready Shop
# 2   3      332 Hill St  San Francisco  California 94114     USA  Super River
# 3   4     3995 23rd St  San Francisco          CA 94114     USA   Ben's Shop
# 4   5  1056 Sanchez St  San Francisco        California     USA      Sanchez
# 5   6  551 Alvarado St  San Francisco          CA 94114     USA   Richvalley
#
#    EMPLOYEES
# 0          8
# 1         15
# 2         25
# 3         10
# 4         12
# 5         20

# %%
df6.set_index["ID"]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-12-117e77ee0691> in <module>
# ----> 1 df6.set_index["ID"]
#
# TypeError: 'method' object is not subscriptable

# %%
import pandas

# %%
df6.set_index("ID")
# Out:
#             ADDRESS           CITY               ZIP COUNTRY         NAME  \
# ID
# 1      3666 21st St  San Francisco          CA 94114     USA      Madeira
# 2    735 Dolores St  San Francisco          CA 94119     USA  Bready Shop
# 3       332 Hill St  San Francisco  California 94114     USA  Super River
# 4      3995 23rd St  San Francisco          CA 94114     USA   Ben's Shop
# 5   1056 Sanchez St  San Francisco        California     USA      Sanchez
# 6   551 Alvarado St  San Francisco          CA 94114     USA   Richvalley
#
#     EMPLOYEES
# ID
# 1           8
# 2          15
# 3          25
# 4          10
# 5          12
# 6          20

# %%
df7=df6.set_index("ID")
df7
# Out:
#             ADDRESS           CITY               ZIP COUNTRY         NAME  \
# ID
# 1      3666 21st St  San Francisco          CA 94114     USA      Madeira
# 2    735 Dolores St  San Francisco          CA 94119     USA  Bready Shop
# 3       332 Hill St  San Francisco  California 94114     USA  Super River
# 4      3995 23rd St  San Francisco          CA 94114     USA   Ben's Shop
# 5   1056 Sanchez St  San Francisco        California     USA      Sanchez
# 6   551 Alvarado St  San Francisco          CA 94114     USA   Richvalley
#
#     EMPLOYEES
# ID
# 1           8
# 2          15
# 3          25
# 4          10
# 5          12
# 6          20

# %%
df7
# Out:
#             ADDRESS           CITY               ZIP COUNTRY         NAME  \
# ID
# 1      3666 21st St  San Francisco          CA 94114     USA      Madeira
# 2    735 Dolores St  San Francisco          CA 94119     USA  Bready Shop
# 3       332 Hill St  San Francisco  California 94114     USA  Super River
# 4      3995 23rd St  San Francisco          CA 94114     USA   Ben's Shop
# 5   1056 Sanchez St  San Francisco        California     USA      Sanchez
# 6   551 Alvarado St  San Francisco          CA 94114     USA   Richvalley
#
#     EMPLOYEES
# ID
# 1           8
# 2          15
# 3          25
# 4          10
# 5          12
# 6          20

# %%
list(df7.loc[:,"NAME"])
# Out:
# [' Madeira',
#  'Bready Shop',
#  'Super River',
#  "Ben's Shop",
#  'Sanchez',
#  'Richvalley']

# %%
df7
# Out:
#             ADDRESS           CITY               ZIP COUNTRY         NAME  \
# ID
# 1      3666 21st St  San Francisco          CA 94114     USA      Madeira
# 2    735 Dolores St  San Francisco          CA 94119     USA  Bready Shop
# 3       332 Hill St  San Francisco  California 94114     USA  Super River
# 4      3995 23rd St  San Francisco          CA 94114     USA   Ben's Shop
# 5   1056 Sanchez St  San Francisco        California     USA      Sanchez
# 6   551 Alvarado St  San Francisco          CA 94114     USA   Richvalley
#
#     EMPLOYEES
# ID
# 1           8
# 2          15
# 3          25
# 4          10
# 5          12
# 6          20

# %%
df7.iloc[2,0:3]
# Out:
# CITY          San Francisco
# ZIP        California 94114
# COUNTRY                 USA
# Name: 332 Hill St, dtype: object

# %%
df7.iloc[2,0]
# Out:
# '332 Hill St'

# %%
df7.set_index("ADDRESS",inplace=True)

# %%
df7.drop("3995 23rd St",0)
# Out:
#                           CITY               ZIP COUNTRY         NAME  \
# ADDRESS
# 3666 21st St     San Francisco          CA 94114     USA      Madeira
# 735 Dolores St   San Francisco          CA 94119     USA  Bready Shop
# 332 Hill St      San Francisco  California 94114     USA  Super River
# 1056 Sanchez St  San Francisco        California     USA      Sanchez
# 551 Alvarado St  San Francisco          CA 94114     USA   Richvalley
#
#                  EMPLOYEES
# ADDRESS
# 3666 21st St             8
# 735 Dolores St          15
# 332 Hill St             25
# 1056 Sanchez St         12
# 551 Alvarado St         20

# %%
df7.drop("EMPLOYEES",1)
# Out:
#             ADDRESS           CITY               ZIP COUNTRY         NAME
# ID
# 1      3666 21st St  San Francisco          CA 94114     USA      Madeira
# 2    735 Dolores St  San Francisco          CA 94119     USA  Bready Shop
# 3       332 Hill St  San Francisco  California 94114     USA  Super River
# 4      3995 23rd St  San Francisco          CA 94114     USA   Ben's Shop
# 5   1056 Sanchez St  San Francisco        California     USA      Sanchez
# 6   551 Alvarado St  San Francisco          CA 94114     USA   Richvalley

# %%
df7.drop(df7.index[0:3],0)
# Out:
#                           CITY         ZIP COUNTRY        NAME  EMPLOYEES
# ADDRESS
# 3995 23rd St     San Francisco    CA 94114     USA  Ben's Shop         10
# 1056 Sanchez St  San Francisco  California     USA     Sanchez         12
# 551 Alvarado St  San Francisco    CA 94114     USA  Richvalley         20

# %%
df7.drop(df7.columns[3:5],1)
# Out:
#                           CITY               ZIP COUNTRY
# ADDRESS
# 3666 21st St     San Francisco          CA 94114     USA
# 735 Dolores St   San Francisco          CA 94119     USA
# 332 Hill St      San Francisco  California 94114     USA
# 3995 23rd St     San Francisco          CA 94114     USA
# 1056 Sanchez St  San Francisco        California     USA
# 551 Alvarado St  San Francisco          CA 94114     USA

# %%
df7.drop?

# %%
df7["CONTINENT"]=['Asia']
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-33-979544bdefcd> in <module>
# ----> 1 df7["CONTINENT"]=['Asia']
#
# c:\users\sree\appdata\local\programs\python\python38-32\lib\site-packages\pandas\core\frame.py in __setitem__(self, key, value)
#    2936         else:
#    2937             # set column
# -> 2938             self._set_item(key, value)
#    2939
#    2940     def _setitem_slice(self, key, value):
#
# c:\users\sree\appdata\local\programs\python\python38-32\lib\site-packages\pandas\core\frame.py in _set_item(self, key, value)
#    2998
#    2999         self._ensure_valid_index(value)
# -> 3000         value = self._sanitize_column(key, value)
#    3001         NDFrame._set_item(self, key, value)
#    3002
#
# ...

# %%
len(df7.index)
# Out:
# 6

# %%
df7.shape
# Out:
# (6, 5)

# %%
df7["CONTINENT"]=df7.shape[0]*["North America"]
df7
# Out:
#                           CITY               ZIP COUNTRY         NAME  \
# ADDRESS
# 3666 21st St     San Francisco          CA 94114     USA      Madeira
# 735 Dolores St   San Francisco          CA 94119     USA  Bready Shop
# 332 Hill St      San Francisco  California 94114     USA  Super River
# 3995 23rd St     San Francisco          CA 94114     USA   Ben's Shop
# 1056 Sanchez St  San Francisco        California     USA      Sanchez
# 551 Alvarado St  San Francisco          CA 94114     USA   Richvalley
#
#                  EMPLOYEES      CONTINENT
# ADDRESS
# 3666 21st St             8  North America
# 735 Dolores St          15  North America
# 332 Hill St             25  North America
# 3995 23rd St            10  North America
# 1056 Sanchez St         12  North America
# 551 Alvarado St         20  North America

# %%
df7["CONTINENT"]=df7["COUNTRY"]+","+df7["CONTINENT"]
df7
# Out:
#                           CITY               ZIP COUNTRY         NAME  \
# ADDRESS
# 3666 21st St     San Francisco          CA 94114     USA      Madeira
# 735 Dolores St   San Francisco          CA 94119     USA  Bready Shop
# 332 Hill St      San Francisco  California 94114     USA  Super River
# 3995 23rd St     San Francisco          CA 94114     USA   Ben's Shop
# 1056 Sanchez St  San Francisco        California     USA      Sanchez
# 551 Alvarado St  San Francisco          CA 94114     USA   Richvalley
#
#                  EMPLOYEES              CONTINENT
# ADDRESS
# 3666 21st St             8  USA,USA,North America
# 735 Dolores St          15  USA,USA,North America
# 332 Hill St             25  USA,USA,North America
# 3995 23rd St            10  USA,USA,North America
# 1056 Sanchez St         12  USA,USA,North America
# 551 Alvarado St         20  USA,USA,North America

# %%
df7_t=df7.T
df7_t
# Out:
# ADDRESS             3666 21st St         735 Dolores St  \
# CITY               San Francisco          San Francisco
# ZIP                     CA 94114               CA 94119
# COUNTRY                      USA                    USA
# NAME                     Madeira            Bready Shop
# EMPLOYEES                      8                     15
# CONTINENT  USA,USA,North America  USA,USA,North America
#
# ADDRESS              332 Hill St           3995 23rd St  \
# CITY               San Francisco          San Francisco
# ZIP             California 94114               CA 94114
# COUNTRY                      USA                    USA
# NAME                 Super River             Ben's Shop
# EMPLOYEES                     25                     10
# CONTINENT  USA,USA,North America  USA,USA,North America
#
# ADDRESS          1056 Sanchez St        551 Alvarado St
# CITY               San Francisco          San Francisco
# ZIP                   California               CA 94114
# ...

# %%
df7_t["My Address"]=["My City","Zip Code","My Country","My Name","My Employees","Continent"]
df7_t
# Out:
# ADDRESS             3666 21st St         735 Dolores St  \
# CITY               San Francisco          San Francisco
# ZIP                     CA 94114               CA 94119
# COUNTRY                      USA                    USA
# NAME                     Madeira            Bready Shop
# EMPLOYEES                      8                     15
# CONTINENT  USA,USA,North America  USA,USA,North America
#
# ADDRESS              332 Hill St           3995 23rd St  \
# CITY               San Francisco          San Francisco
# ZIP             California 94114               CA 94114
# COUNTRY                      USA                    USA
# NAME                 Super River             Ben's Shop
# EMPLOYEES                     25                     10
# CONTINENT  USA,USA,North America  USA,USA,North America
#
# ADDRESS          1056 Sanchez St        551 Alvarado St    My Address
# CITY               San Francisco          San Francisco       My City
# ...

# %%
df7=df7_t.T
df7
# Out:
#                           CITY               ZIP     COUNTRY         NAME  \
# ADDRESS
# 3666 21st St     San Francisco          CA 94114         USA      Madeira
# 735 Dolores St   San Francisco          CA 94119         USA  Bready Shop
# 332 Hill St      San Francisco  California 94114         USA  Super River
# 3995 23rd St     San Francisco          CA 94114         USA   Ben's Shop
# 1056 Sanchez St  San Francisco        California         USA      Sanchez
# 551 Alvarado St  San Francisco          CA 94114         USA   Richvalley
# My Address             My City          Zip Code  My Country      My Name
#
#                     EMPLOYEES              CONTINENT
# ADDRESS
# 3666 21st St                8  USA,USA,North America
# 735 Dolores St             15  USA,USA,North America
# 332 Hill St                25  USA,USA,North America
# 3995 23rd St               10  USA,USA,North America
# 1056 Sanchez St            12  USA,USA,North America
# ...
